# %% [markdown]
# # 3. Check Dataset
# This file performes some checks. They must not all workout, but you will have far bether results by fixing it!

# %%
import pandas as pd
import numpy as np
import sys

# %%
df_raw = pd.read_csv('../../data/3. transformation/2_list_all_cleaned.csv')

# %% [markdown]
# ## Empty HCP-Address check
# You should not have any rows withouth an address

# %%
df_raw[df_raw.address.isna() & (df_raw.type == 'hcp')]
# Out:
#       internalid                 name      location country address     plz  \
# 860          861       Stefan Greuter       Sargans      CH     NaN     NaN
# 1018        1019      Sara Steffanoni    Bellinzona      CH     NaN     NaN
# 2547        2548     Jean Paul Schmid    Barmelweid      CH     NaN  5017.0
# 4356        4357  Mirjam Christ-Crain         Basel      CH     NaN     NaN
# 4368        4369    Brigitte Rodinger         Basel      CH     NaN     NaN
# 4868        4869     Georg Steinfurth           NaN      CH     NaN     NaN
# 5334        5335         Tobias Paust           NaN      CH     NaN     NaN
# 5335        5336        Pascal Burger           NaN      CH     NaN     NaN
# 5615        5616      Christine Kunze  Diessenhofen      CH     NaN     NaN
# 5629        5630    Francesco Madonia          Cama      CH     NaN     NaN
# 5667        5668        Nazim Reshiti  Diessenhofen      CH     NaN     NaN
# 9966        9967      Cécile Robinson        Zürich      CH     NaN     NaN
#
#                 uci  donations_grants  sponsorship  registration_fees  \
# 860             NaN               NaN          NaN              154.0
# 1018            NaN               NaN          NaN              154.0
# 2547       40762856               0.0          0.0                0.0
# 4356  7601000625311               NaN          NaN                NaN
# 4368            NaN               NaN          NaN                NaN
# 4868            NaN               NaN          NaN               65.3
# 5334            NaN               NaN          NaN                NaN
# 5335            NaN               NaN          NaN                NaN
# 5615            NaN               NaN          NaN                NaN
# 5629            NaN               NaN          NaN              338.0
# 5667            NaN               NaN          NaN              595.0
# 9966            NaN               NaN          NaN                NaN
#
#       travel_accommodation     fees  related_expenses    total type  \
# 860                  77.00      NaN               NaN   231.00  hcp
# 1018                 77.00      NaN               NaN   231.00  hcp
# 2547                  0.00   700.00              0.00   700.00  hcp
# 4356                   NaN  4734.77           1106.92  5841.69  hcp
# 4368                210.84      NaN               NaN   210.84  hcp
# 4868                123.70     0.00              0.00   189.00  hcp
# 5334                   NaN  1600.00               NaN  1600.00  hcp
# 5335                   NaN      NaN           1047.00  1047.00  hcp
# 5615                336.00   513.00               NaN   849.00  hcp
# 5629               1001.00      NaN               NaN  1339.00  hcp
# 5667               1118.00      NaN               NaN  1713.00  hcp
# 9966                   NaN   750.00               NaN   750.00  hcp
#
#            source
# 860         amgen
# 1018        amgen
# 2547        bayer
# 4356       future
# 4368       future
# 4868  gruenenthal
# 5334     lundbeck
# 5335     lundbeck
# 5615     menarini
# 5629     menarini
# 5667     menarini
# 9966         teva

# %% [markdown]
# ## Check for empty name

# %%
df_raw[df_raw.name.isna()]
# Out:
# Empty DataFrame
# Columns: [internalid, name, location, country, address, plz, uci, donations_grants, sponsorship, registration_fees, travel_accommodation, fees, related_expenses, total, type, source]
# Index: []

# %% [markdown]
# ## Check Sources
# Are sources correct?

# %%
df_sources = pd.read_csv('../6. database export/sources/liste_companies.csv')
    
#Join
df_raw = df_raw.merge(df_sources, how='left', left_on='source', right_on='pha_key')
df_raw[df_raw.pha_name.isna()]
# Out:
# Empty DataFrame
# Columns: [internalid, name, location, country, address, plz, uci, donations_grants, sponsorship, registration_fees, travel_accommodation, fees, related_expenses, total, type, source, pha_id, pha_key, pha_name]
# Index: []
