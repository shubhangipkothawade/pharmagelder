# %% [markdown]
# # 3. Check Dataset
# This file performes some checks. They must not all workout, but you will have far bether results by fixing it!

# %%
import pandas as pd
import numpy as np
import sys

# %%
df_raw = pd.read_csv('../../data/3. transformation/2_list_all_cleaned.csv')

# %% [markdown]
# ## Empty HCP-Address check
# You should not have any rows withouth an address

# %%
df_raw[df_raw.address.isna() & (df_raw.type == 'hcp')]
# Out:
#                           name           location country address  plz  \
# 4090             Volker Wedler        Kreuzlingen      CH     NaN  NaN
# 5215         Francesco Madonia               Cama      CH     NaN  NaN
# 5217         Christopher Marti           Novaggio      CH     NaN  NaN
# 6255         Jonathan Gonzalez             Genève      CH     NaN  NaN
# 8479          Richard Herrmann                NaN      CH     NaN  NaN
# 12313  Laurence Perrin Barelli          Pompaples      CH     NaN  NaN
# 12318         Emilie Solimando          Neuchâtel      CH     NaN  NaN
# 12546        Christoph Schmidt         Barmelweid      CH     NaN  NaN
# 13378      Hans-Martin Gruenig         Bruderholz      CH     NaN  NaN
# 15580        Francesco Madonia               Cama      CH     NaN  NaN
# 15630          Matteo Prencipe             Osogna      CH     NaN  NaN
# 16668             Photis Beris             Genève      CH     NaN  NaN
# 16669        Berenice Deletang             Genève      CH     NaN  NaN
# 16670           Thomas Matthes             Genève      CH     NaN  NaN
# 16671             Sophie Voruz           Lausanne      CH     NaN  NaN
# 16672          Caroline Zwicky           Lausanne      CH     NaN  NaN
# 16673           Barbara Gugger               Bern      CH     NaN  NaN
# 16674        Johannes Strasser              Basel      CH     NaN  NaN
# 16675          Mahdieh Wölffer       Kirchlindach      CH     NaN  NaN
# 16676              Roger Mäder         St. Gallen      CH     NaN  NaN
# 16677               Thilo Beck             Zürich      CH     NaN  NaN
# 16678      Marie-Claude Blaser  La Chaux-de-Fonds      CH     NaN  NaN
# 16679           Jérôme Cluzeau  La Chaux-de-Fonds      CH     NaN  NaN
# 16680           Jacques Eicher           Lausanne      CH     NaN  NaN
# 16681        Mohamed Hachaichi             Prilly      CH     NaN  NaN
# 16682        Nathalie Jacquard           Lausanne      CH     NaN  NaN
# 16683            Laurianne Mer  Yverdon-les-Bains      CH     NaN  NaN
# 16684          Mirjana Nozinic           Fribourg      CH     NaN  NaN
# 16685               Anne Pelet          Neuchâtel      CH     NaN  NaN
# 16686             Nuré Santoro     Chêne-Bougries      CH     NaN  NaN
# ...                        ...                ...     ...     ...  ...
# 28053     Andreas Siegenthaler               Bern      CH     NaN  NaN
# 28054            Bernhard Hess             Zürich      CH     NaN  NaN
# 28055     Christoph Clarenbach             Zürich      CH     NaN  NaN
# 28056            Konrad Maurer             Zürich      CH     NaN  NaN
# 28057       Panagiotis Samaras             Zürich      CH     NaN  NaN
# 28058            Sophie Pautex             Genève      CH     NaN  NaN
# 28059            Andreas Lohri            Liestal      CH     NaN  NaN
# 28060     Anne-Françoise Allaz             Genève      CH     NaN  NaN
# 28061       Christoph Driessen         St. Gallen      CH     NaN  NaN
# 28062         Daniel Betticher           Fribourg      CH     NaN  NaN
# 28063          Daniele Zullino             Genève      CH     NaN  NaN
# 28064          Daniele Zullino             Genève      CH     NaN  NaN
# 28065                 Eli Alon             Zürich      CH     NaN  NaN
# 28066             Lutz Freitag             Zürich      CH     NaN  NaN
# 28067           Malcolm Kohler             Zürich      CH     NaN  NaN
# 28068               Marco Pons             Lugano      CH     NaN  NaN
# 28069           Mario Bargetzi              Basel      CH     NaN  NaN
# 28070         Matthias Liechti              Basel      CH     NaN  NaN
# 28071          Matthias Schmid             Zürich      CH     NaN  NaN
# 28072        Michele Ghielmini         Bellinzona      CH     NaN  NaN
# 28073             Peter Schmid             Zürich      CH     NaN  NaN
# 28074           Wolf Langewitz              Basel      CH     NaN  NaN
# 28075              Roger Mäder         St. Gallen      CH     NaN  NaN
# 28076           Stephanie Fehr             Zürich      CH     NaN  NaN
# 28077            Thomas Müller              Basel      CH     NaN  NaN
# 28078             Ulrich Krebs               Thun      CH     NaN  NaN
# 28203              Martin Frey         Barmelweid      CH     NaN  NaN
# 28423          Matteo Prencipe             Osogna      CH     NaN  NaN
# 28433       Peter Rickenbacher         Bruderholz      CH     NaN  NaN
# 29551         Reto Arthur Frey                NaN      CH     NaN  NaN
#
#                  uci  donations_grants  sponsorship  registration_fees  \
# 4090   7601000404282               NaN          NaN                NaN
# 5215             NaN               NaN          NaN              353.4
# 5217             NaN               NaN          NaN              353.4
# 6255             NaN               NaN          NaN                NaN
# 8479             NaN               NaN          NaN                0.0
# 12313            NaN               0.0          0.0                0.0
# 12318            NaN               0.0          0.0                0.0
# 12546            NaN               0.0          0.0                0.0
# 13378            NaN               NaN          NaN                NaN
# 15580            NaN               NaN          NaN              247.0
# 15630            NaN               NaN          NaN              247.0
# 16668            NaN               NaN          NaN              102.0
# 16669            NaN               NaN          NaN              102.0
# 16670            NaN               NaN          NaN              102.0
# 16671            NaN               NaN          NaN              102.0
# 16672            NaN               NaN          NaN              102.0
# 16673            NaN               NaN          NaN              103.0
# 16674            NaN               NaN          NaN              103.0
# 16675            NaN               NaN          NaN              103.0
# 16676            NaN               NaN          NaN              103.0
# 16677            NaN               NaN          NaN              103.0
# 16678            NaN               NaN          NaN              249.0
# 16679            NaN               NaN          NaN              249.0
# 16680            NaN               NaN          NaN              249.0
# 16681            NaN               NaN          NaN              125.0
# 16682            NaN               NaN          NaN              249.0
# 16683            NaN               NaN          NaN              249.0
# 16684            NaN               NaN          NaN              249.0
# 16685            NaN               NaN          NaN              249.0
# 16686            NaN               NaN          NaN              249.0
# ...              ...               ...          ...                ...
# 28053            NaN               0.0          0.0              537.0
# 28054            NaN               0.0          0.0                0.0
# 28055            NaN               0.0          0.0              291.0
# 28056            NaN               0.0          0.0                0.0
# 28057            NaN               0.0          0.0              666.0
# 28058            NaN               0.0          0.0              292.0
# 28059            NaN               0.0          0.0                0.0
# 28060            NaN               0.0          0.0                0.0
# 28061            NaN               0.0          0.0              660.0
# 28062            NaN               0.0          0.0                0.0
# 28063            NaN               0.0          0.0              101.0
# 28064            NaN               0.0          0.0              216.0
# 28065            NaN               0.0          0.0                0.0
# 28066            NaN               0.0          0.0                0.0
# 28067            NaN               0.0          0.0                0.0
# 28068            NaN               0.0          0.0              460.0
# 28069            NaN               0.0          0.0                0.0
# 28070            NaN               0.0          0.0                0.0
# 28071            NaN               0.0          0.0                0.0
# 28072            NaN               0.0          0.0                0.0
# 28073            NaN               0.0          0.0                0.0
# 28074            NaN               0.0          0.0                0.0
# 28075            NaN               0.0          0.0              152.0
# 28076            NaN               0.0          0.0              152.0
# 28077            NaN               0.0          0.0                0.0
# 28078            NaN               0.0          0.0              152.0
# 28203            NaN               0.0          0.0                0.0
# 28423            NaN               0.0          0.0             1150.0
# 28433            NaN               0.0          0.0                0.0
# 29551            NaN               0.0          0.0                0.0
#
#        travel_accommodation     fees  related_expenses    total type  \
# 4090                    NaN  8311.45               NaN  8311.45  hcp
# 5215                 828.00      NaN               NaN  1181.40  hcp
# 5217                 826.00      NaN               NaN  1179.40  hcp
# 6255                    NaN    10.00               NaN    10.00  hcp
# 8479                   0.00  2100.00           3635.59  5735.59  hcp
# 12313               1920.00     0.00              0.00  1920.00  hcp
# 12318                940.31     0.00              0.00   940.31  hcp
# 12546                  0.00   700.00              0.00   700.00  hcp
# 13378                   NaN   800.00               NaN   800.00  hcp
# 15580                790.00      NaN               NaN  1037.00  hcp
# 15630                790.00      NaN               NaN  1037.00  hcp
# 16668                785.00     0.00              0.00   887.00  hcp
# 16669                758.00     0.00              0.00   860.00  hcp
# 16670                900.00     0.00              0.00  1002.00  hcp
# 16671                788.00     0.00              0.00   890.00  hcp
# 16672                781.00     0.00              0.00   883.00  hcp
# 16673                477.00     0.00              0.00   580.00  hcp
# 16674                585.00     0.00              0.00   688.00  hcp
# 16675                585.00     0.00              0.00   688.00  hcp
# 16676                503.00     0.00              0.00   606.00  hcp
# 16677                511.00     0.00              0.00   614.00  hcp
# 16678                621.00     0.00              0.00   870.00  hcp
# 16679                513.00     0.00              0.00   762.00  hcp
# 16680                759.00     0.00              0.00  1008.00  hcp
# 16681                615.00     0.00              0.00   740.00  hcp
# 16682                416.00     0.00              0.00   665.00  hcp
# 16683                450.00     0.00              0.00   699.00  hcp
# 16684                618.00     0.00              0.00   867.00  hcp
# 16685                574.00     0.00              0.00   823.00  hcp
# 16686                543.00     0.00              0.00   792.00  hcp
# ...                     ...      ...               ...      ...  ...
# 28053                597.00     0.00              0.00  1134.00  hcp
# 28054                  0.00  3720.00              0.00  3720.00  hcp
# 28055                295.00  1500.00              0.00  2086.00  hcp
# 28056                  0.00  3151.00              0.00  3151.00  hcp
# 28057                838.00     0.00              0.00  1504.00  hcp
# 28058                664.00     0.00              0.00   956.00  hcp
# 28059                  0.00  1000.00              0.00  1000.00  hcp
# 28060                  0.00  1000.00              0.00  1000.00  hcp
# 28061               2132.00     0.00              0.00  2792.00  hcp
# 28062                  0.00  2500.00              0.00  2500.00  hcp
# 28063                413.00     0.00              0.00   514.00  hcp
# 28064                467.00     0.00              0.00   683.00  hcp
# 28065                510.00     0.00              0.00   510.00  hcp
# 28066                637.00     0.00              0.00   637.00  hcp
# 28067                  0.00  1500.00              0.00  1500.00  hcp
# 28068                936.00     0.00              0.00  1396.00  hcp
# 28069                  0.00  1500.00              0.00  1500.00  hcp
# 28070                  0.00  7200.00              0.00  7200.00  hcp
# 28071                  0.00  1500.00              0.00  1500.00  hcp
# 28072                  0.00  2500.00              0.00  2500.00  hcp
# 28073                  0.00  2500.00              0.00  2500.00  hcp
# 28074                  0.00  1500.00            150.00  1650.00  hcp
# 28075                188.00     0.00              0.00   340.00  hcp
# 28076                193.00     0.00              0.00   345.00  hcp
# 28077                363.00     0.00              0.00   363.00  hcp
# 28078                656.00     0.00              0.00   808.00  hcp
# 28203                  0.00  2600.00              0.00  2600.00  hcp
# 28423               1150.00     0.00              0.00  2300.00  hcp
# 28433                  0.00  1000.00              0.00  1000.00  hcp
# 29551                  0.00   500.00              0.00   500.00  hcp
#
#             source _export_information  year
# 4090      galderma                 NaN  2017
# 5215      menarini                 NaN  2017
# 5217      menarini                 NaN  2017
# 6255   mundipharma                 NaN  2017
# 8479         roche                 NaN  2017
# 12313       baxter                 NaN  2016
# 12318       baxter                 NaN  2016
# 12546        bayer                 NaN  2016
# 13378      bristol                 NaN  2016
# 15580     menarini                 NaN  2016
# 15630     menarini                 NaN  2016
# 16668  mundipharma                 NaN  2016
# 16669  mundipharma                 NaN  2016
# 16670  mundipharma                 NaN  2016
# 16671  mundipharma                 NaN  2016
# 16672  mundipharma                 NaN  2016
# 16673  mundipharma                 NaN  2016
# 16674  mundipharma                 NaN  2016
# 16675  mundipharma                 NaN  2016
# 16676  mundipharma                 NaN  2016
# 16677  mundipharma                 NaN  2016
# 16678  mundipharma                 NaN  2016
# 16679  mundipharma                 NaN  2016
# 16680  mundipharma                 NaN  2016
# 16681  mundipharma                 NaN  2016
# 16682  mundipharma                 NaN  2016
# 16683  mundipharma                 NaN  2016
# 16684  mundipharma                 NaN  2016
# 16685  mundipharma                 NaN  2016
# 16686  mundipharma                 NaN  2016
# ...            ...                 ...   ...
# 28053  mundipharma                 NaN  2015
# 28054  mundipharma                 NaN  2015
# 28055  mundipharma                 NaN  2015
# 28056  mundipharma                 NaN  2015
# 28057  mundipharma                 NaN  2015
# 28058  mundipharma                 NaN  2015
# 28059  mundipharma                 NaN  2015
# 28060  mundipharma                 NaN  2015
# 28061  mundipharma                 NaN  2015
# 28062  mundipharma                 NaN  2015
# 28063  mundipharma                 NaN  2015
# 28064  mundipharma                 NaN  2015
# 28065  mundipharma                 NaN  2015
# 28066  mundipharma                 NaN  2015
# 28067  mundipharma                 NaN  2015
# 28068  mundipharma                 NaN  2015
# 28069  mundipharma                 NaN  2015
# 28070  mundipharma                 NaN  2015
# 28071  mundipharma                 NaN  2015
# 28072  mundipharma                 NaN  2015
# 28073  mundipharma                 NaN  2015
# 28074  mundipharma                 NaN  2015
# 28075  mundipharma                 NaN  2015
# 28076  mundipharma                 NaN  2015
# 28077  mundipharma                 NaN  2015
# 28078  mundipharma                 NaN  2015
# 28203     novartis                 NaN  2015
# 28423     novartis                 NaN  2015
# 28433     novartis                 NaN  2015
# 29551        roche                 NaN  2015
#
# [279 rows x 17 columns]

# %% [markdown]
# ## Check for empty name

# %%
df_raw[df_raw.name.isna()]
# Out:
# Empty DataFrame
# Columns: [name, location, country, address, plz, uci, donations_grants, sponsorship, registration_fees, travel_accommodation, fees, related_expenses, total, type, source, _export_information, year]
# Index: []

# %% [markdown]
# ## Check Sources
# Are sources correct?

# %%
df_sources = pd.read_csv('../6. database export/sources/liste_companies - connections.csv')
    
#Join
df_raw = df_raw.merge(df_sources, how='left', left_on='source', right_on='pha_key')
df_raw[df_raw.pha_name.isna()]
# Out:
# Empty DataFrame
# Columns: [name, location, country, address, plz, uci, donations_grants, sponsorship, registration_fees, travel_accommodation, fees, related_expenses, total, type, source, _export_information, year, pha_id_x, pha_key_x, pha_name_x, pha_id_y, pha_key_y, pha_name_y, pha_id, pha_key, pha_name]
# Index: []
#
# [0 rows x 26 columns]
