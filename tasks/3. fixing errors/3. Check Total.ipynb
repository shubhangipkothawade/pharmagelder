# %% [markdown]
# # Check Total
# This script checks the total again. You never know!

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
import time

import sys
sys.path.insert(0, '../../data/lib/')

import pandas as pd
import importlib

import pdfexport
importlib.reload(pdfexport)

from pdfexport import *

# %%
#df = pd.read_csv('../../data/2. manual check/lists/novartis.csv')
df = pd.read_csv('../../data/3. transformation/2_list_all_cleaned.csv')

df_data = df.copy()
df_data.drop(['location', 'country', 'plz', 'uci', 'address'], axis=1, inplace=True)
#df_data = df[df.source == 'novartis']

df_data = df_data.fillna(0)

df_data['total_check'] = df_data.apply(lambda row: round(row['donations_grants'] 
                                      + row['sponsorship']
                                      + row['registration_fees']
                                      + row['travel_accommodation']
                                      + row['fees']
                                      + row['related_expenses'], 2)
                                      ,axis = 1)
df_data['dif'] = abs(df_data.total - df_data.total_check)

# %%
#df_data[(df_data.dif > 2) & (df_data.source == 'menarini')]
#df_data['CHECK'] = df_data.apply(lambda row: row['dif'] > 0, axis=1)
#df_data[(df_data.source == 'takeda')].to_csv('tmp.csv', sep=';')
df_data[df_data.dif > 2]
# Out:
#                                                     name  donations_grants  \
# 582                              Claudia Krieger-Gruebel               0.0
# 606                                     Susanne Reichert               0.0
# 608                                      Philippe Snozzi               0.0
# 618                                     Peter Schöneborn               0.0
# 625                                         Volker Stenz               0.0
# 626                                         Walter Suter               0.0
# 627                                     Stansilav Svaral               0.0
# 645                                                 CHUV               0.0
# 651                             Kantonsspital St. Gallen               0.0
# 4242                                                CHUV           19500.0
# 4552                                                CHUV               0.0
# ...
